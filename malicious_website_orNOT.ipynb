# %%
# !pip install python-whois tldextract requests beautifulsoup4
# Out:
# Collecting python-whois
#   Downloading python_whois-0.9.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting tldextract
#   Downloading tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from python-whois) (2.9.0.post0)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from tldextract) (3.11)
# Collecting requests-file>=1.4 (from tldextract)
#   Downloading requests_file-3.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.12/dist-packages (from tldextract) (3.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->python-whois) (1.17.0)
# Downloading python_whois-0.9.6-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.8 MB/s eta 0:00:00
# Downloading tldextract-5.3.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 9.4 MB/s eta 0:00:00
# Downloading requests_file-3.0.0-py2.py3-none-any.whl (4.5 kB)
# Installing collected packages: requests-file, python-whois, tldextract
# Successfully installed python-whois-0.9.6 requests-file-3.0.0 tldextract-5.3.0

# %%
import pandas as pd
import joblib
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from extractor import extract_website_features  # your feature extractor
import warnings
warnings.filterwarnings("ignore")

# File paths
DATASET_FILE = "website_security_dataset.csv"

# Optional: delay for feature extraction if predicting multiple URLs
import time
DELAY = 0.5

# %%
# Load your CSV
df = pd.read_csv(DATASET_FILE)
print("Dataset loaded:", df.shape)
df.head()
# Out:
# Dataset loaded: (999, 26)
#                   Website  has_https  ssl_valid  ssl_expiry_days  \
# 0        https://ucla.edu          1          1              333
# 1    https://netangels.ru          1          1               71
# 2  https://sharepoint.com          1          1              224
# 3          https://ptt.cc          0          0                0
# 4    https://newsweek.com          1          1              289
#
#               ssl_issuer  domain_age_days  whois_info_available  \
# 0                 Amazon            14787                     1
# 1          Let's Encrypt             7991                     1
# 2  Microsoft Corporation             9931                     1
# 3                    NaN             8674                     1
# 4                 Amazon            11477                     1
#
#        organization_name  url_length  num_dots  ...  num_external_links  \
# 0                    NaN          16         1  ...                 151
# 1     LLP "Internet-Pro"          20         1  ...                  45
# 2  Microsoft Corporation          22         1  ...                   1
# 3                    NaN          14         1  ...                   0
# 4  Newsweek Magazine LLC          20         1  ...                 281
#
#    has_login_keyword  has_privacy_policy has_contact_page  \
# 0                  0                   1                1
# 1                  0                   0                1
# 2                  0                   0                0
# 3                  0                   0                0
# 4                  1                   1                1
#
#    num_suspicious_keywords  has_hsts_header  has_x_frame_options  has_csp  \
# 0                        0                0                    1        0
# 1                        0                0                    0        0
# 2                        0                1                    0        0
# 3                        0                0                    0        0
# 4                        0                1                    1        0
#
#    has_x_content_type_options  secure_label
# 0                           1             1
# 1                           0             1
# 2                           0             1
# 3                           0             1
# 4                           1             1
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#                                                Website  has_https  ssl_valid  \
# 994  http://answers.ask.com/Entertainment/Music/who...          0          0
# 995          http://www.ringsurf.com/ring/digitalring/          0          0
# 996                  http://www.hp.com/sbso/index.html          0          0
# 997  http://reuters.com/finance/stocks/companyOffic...          0          0
# 998  http://divxturka.net/mkv-mp4-rmvb-movies/10926...          0          0
#
#      ssl_expiry_days ssl_issuer  domain_age_days  whois_info_available  \
# 994                0        NaN             9860                     1
# 995                0        NaN             9923                     1
# 996                0        NaN            14474                     1
# 997                0        NaN            11825                     1
# 998                0        NaN             6638                     1
#
#                           organization_name  url_length  num_dots  ...  \
# 994                                 Ask.com          61         2  ...
# 995                    REDACTED FOR PRIVACY          41         2  ...
# 996                                 HP Inc.          33         3  ...
# 997  Thomson Reuters Enterprise Centre GmbH          63         2  ...
# 998                   Domains By Proxy, LLC          90         2  ...
#
#      num_external_links  has_login_keyword  has_privacy_policy  \
# 994                   0                  0                   0
# 995                   0                  0                   0
# 996                   0                  0                   0
# 997                   0                  0                   0
# 998                   0                  0                   0
#
#     has_contact_page  num_suspicious_keywords  has_hsts_header  \
# 994                0                        0                0
# 995                0                        0                0
# 996                0                        0                0
# 997                0                        0                0
# 998                1                        0                0
#
#      has_x_frame_options  has_csp  has_x_content_type_options  secure_label
# 994                    0        0                           0             0
# 995                    0        0                           0             0
# 996                    0        0                           0             0
# 997                    0        1                           0             0
# 998                    0        0                           0             0
#
# [5 rows x 26 columns]

# %%
# Drop Website column for training
X = df.drop(columns=["Website", "secure_label"])
y = df["secure_label"]

# One-hot encode categorical features
X = pd.get_dummies(X, columns=["ssl_issuer", "organization_name", "tld_type"])

# Scale numeric features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Save columns for later prediction
X_columns = X.columns.tolist()

print("Features prepared. Total features:", len(X_columns))
# Out:
# Features prepared. Total features: 323

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)
print("Training set:", X_train.shape)
print("Test set:", X_test.shape)
# Out:
# Training set: (799, 323)
# Test set: (200, 323)

# %%
model = RandomForestClassifier(n_estimators=200, random_state=42)
model.fit(X_train, y_train)
print("✅ Model trained successfully")
# Out:
# ✅ Model trained successfully

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.99
#
# Confusion Matrix:
#  [[104   2]
#  [  0  94]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       106
#            1       0.98      1.00      0.99        94
#
#     accuracy                           0.99       200
#    macro avg       0.99      0.99      0.99       200
# weighted avg       0.99      0.99      0.99       200

# %%
joblib.dump(model, "website_classifier.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(X_columns, "X_columns.pkl")
print("✅ Model, scaler, and feature columns saved")
# Out:
# ✅ Model, scaler, and feature columns saved

# %%
# Load X_columns for prediction
X_columns = joblib.load("X_columns.pkl")
scaler = joblib.load("scaler.pkl")
model = joblib.load("website_classifier.pkl")

def extract_features_for_prediction(url):
    """Extract features from a URL and prepare dataframe for prediction"""
    features = extract_website_features(url, labels={"secure_label": 1})
    df_features = pd.DataFrame([features])

    # One-hot encode categorical columns
    df_features = pd.get_dummies(df_features, columns=["ssl_issuer", "organization_name", "tld_type"])

    # Align columns with training features
    for col in X_columns:
        if col not in df_features.columns:
            df_features[col] = 0
    df_features = df_features[X_columns]
    return df_features

# %%
def predict_website(url):
    df_features = extract_features_for_prediction(url)
    df_scaled = scaler.transform(df_features)
    pred = model.predict(df_scaled)[0]
    prob = model.predict_proba(df_scaled)[0][pred]

    if pred == 1:
        print(f"✅ {url} is likely SAFE ({prob*100:.2f}% confidence)")
    else:
        print(f"⚠️ {url} is likely MALICIOUS ({prob*100:.2f}% confidence)")

# %%
url = input("Enter a URL to check: ")
predict_website(url)
# Out:
# Enter a URL to check: chatgpt.com
# ✅ chatgpt.com is likely SAFE (100.00% confidence)

# %%
url = input("Enter a URL to check: ")
predict_website(url)
# Out:
# Enter a URL to check: www.giss.nasa.gov/tools/
# ⚠️ www.giss.nasa.gov/tools/ is likely MALICIOUS (97.00% confidence)

# %%
predict_website("http://fakebank-login.com")
# Out:
# ⚠️ http://fakebank-login.com is likely MALICIOUS (76.00% confidence)

# %%
predict_website("https://www.nasa.gov")
# Out:
# ✅ https://www.nasa.gov is likely SAFE (93.00% confidence)
